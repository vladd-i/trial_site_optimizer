# %% [markdown]
# ## Test Modules

# %%
# Import necessary modules
import sys
sys.path.append('..')  # Adjust the path to ensure it correctly points to the project root.

import pandas as pd
from src.data.dataloader import DataLoader  # Update the import path based on your project structure

# %%
# Initialize the DataLoader
dataloader = DataLoader()

# Load and preprocess the data, merge datasets, impute missing values, and apply feature engineering
X, y = dataloader.get_data()

X_train, y_train, X_val, y_val, X_test, y_test = dataloader.get_train_val_test_split()
# Out:
# /Users/vlad_ivanchuk/opt/anaconda3/envs/cs109a/lib/python3.9/site-packages/pandas/core/frame.py:3673: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[col] = igetitem(value, i)
# /Users/vlad_ivanchuk/opt/anaconda3/envs/cs109a/lib/python3.9/site-packages/pandas/core/generic.py:6392: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self._update_inplace(result)
# /Users/vlad_ivanchuk/opt/anaconda3/envs/cs109a/lib/python3.9/site-packages/pandas/core/frame.py:3673: SettingWithCopyWarning:
# ...

# %%
display(X_train.info())
display(X_train.describe())
display(y_train.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 853 entries, 0 to 1329
# Data columns (total 77 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   population                                     853 non-null    float64
#  1   oecd_pharma_expenditure_per_capita             853 non-null    float64
#  2   oecd_medical_grads_per_1k                      853 non-null    float64
#  3   oecd_MDs_per_1k                                853 non-null    float64
#  4   oecd_hospital_beds_per_1k                      853 non-null    float64
#  5   oecd_MR_units_per_1m                           853 non-null    float64
#  6   oecd_pte_units_total                           853 non-null    float64
#  7   oecd_perc_pop_insured_by_gov_health            853 non-null    float64
#  8   oecd_perc_pop_insured_by_priv_health           853 non-null    float64
# ...

# %%
display(X_val.info())
display(X_val.describe())
display(y_val.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 202 entries, 1 to 1326
# Data columns (total 77 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   population                                     202 non-null    float64
#  1   oecd_pharma_expenditure_per_capita             202 non-null    float64
#  2   oecd_medical_grads_per_1k                      202 non-null    float64
#  3   oecd_MDs_per_1k                                202 non-null    float64
#  4   oecd_hospital_beds_per_1k                      202 non-null    float64
#  5   oecd_MR_units_per_1m                           202 non-null    float64
#  6   oecd_pte_units_total                           202 non-null    float64
#  7   oecd_perc_pop_insured_by_gov_health            202 non-null    float64
#  8   oecd_perc_pop_insured_by_priv_health           202 non-null    float64
# ...

# %%
display(X_test.info())
display(X_test.describe())
display(y_test.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 98 entries, 4 to 1321
# Data columns (total 77 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   population                                     98 non-null     float64
#  1   oecd_pharma_expenditure_per_capita             98 non-null     float64
#  2   oecd_medical_grads_per_1k                      98 non-null     float64
#  3   oecd_MDs_per_1k                                98 non-null     float64
#  4   oecd_hospital_beds_per_1k                      98 non-null     float64
#  5   oecd_MR_units_per_1m                           98 non-null     float64
#  6   oecd_pte_units_total                           98 non-null     float64
#  7   oecd_perc_pop_insured_by_gov_health            98 non-null     float64
#  8   oecd_perc_pop_insured_by_priv_health           98 non-null     float64
# ...
